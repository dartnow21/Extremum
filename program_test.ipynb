# %% [markdown]
# # Поиск экстремумов

# %%
# !git clone https://github.com/dartnow21/Extremum
# Out:
# Cloning into 'Extremum'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 46 (delta 22), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (46/46), 375.06 KiB | 1.86 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
from Extremum.User import *
from Extremum.SearchExtremes import *
from Extremum.MethodLagranja import *

# %%
type(User)
# Out:
# type

# %%
functions = SearchExtremes()
functions.find()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-4d685b66d2cd> in <module>
#       1 functions = SearchExtremes()
# ----> 2 functions.find()
#
# TypeError: find() missing 7 required positional arguments: 'x', 'y', 'z', 'x_from', 'x_to', 'y_from', and 'y_to'

# %% [markdown]
# ## Оберточная функция

# %% [markdown]
# Создана для упрощения работы с программой обычных пользователей

# %% [markdown]
# ## Примеры работы с программой

# %% [markdown]
# Обычный метод (вращающийся 3д график будет в отдельном окне после запуска)

# %%
# %matplotlib qt

functions = User()
functions.userAnswer()
# Out:
# Каким методом для нахождения экстремумов хотите воспользоваться? 1 - Обычный способ / 2 - Метод Лагранжа
# 1
# Введите функцию f(x, y). Например:  x**2 + y ** 2 + 1
# x**2 + y ** 2 + 1
# Есть ли ограничения по x и y? 1-да / 0 – нет
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-cae58e199361> in <module>
#       2
#       3 functions = User()
# ----> 4 functions.userAnswer()
#
# ~/Documents/оптимизационные задачи в машинном обучении/1lab/Extremum/User.py in userAnswer(self)
#      28                 print("Введите точку от. Пример: -10")
#      29                 y_from = float(input())
# ---> 30                 print("Введите точку до. Пример: 10")
#      31                 y_to = float(input())
#      32             functions1 = SearchExtremes()
#
# NameError: name 'SearchExtremes' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Метод лагранжа (вращающийся 3д график будет в отдельном окне после запуска)

# %%
functions = User()
functions.userAnswer()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
functions1 = SearchExtremes()
functions1.find(x, y, f, x_from, x_to, y_from, y_to)
