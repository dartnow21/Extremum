# %% [markdown]
# # Поиск экстремумов

# %%
# !git clone https://github.com/dartnow21/Extremum
# Out:
# fatal: destination path 'Extremum' already exists and is not an empty directory.

# %%
from Extremum.User import *
from Extremum.SearchExtremes import *
from Extremum.MethodLagranja import *

# %% [markdown]
# Для корректной работы нашей программы требуется matplotlib версии '3.5.1'

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.5.1'

# %% [markdown]
# ## Примеры работы с программой

# %% [markdown]
# Для запуска программы нужно обратиться к классу User() и функции userAnswer() и далее действовать согласно примерам представляемым программой

# %% [markdown]
# Обычный метод (вращающийся 3д график будет в отдельном окне если в начале добавить %matplotlib qt )

# %%
# %matplotlib qt

functions = User()
functions.userAnswer()
# Out:
# Каким методом для нахождения экстремумов хотите воспользоваться? 1 - Обычный способ / 2 - Метод Лагранжа
# 1
# Введите функцию f(x, y). Например:  x**2 + y ** 2 + 1
# (x**2)/8+(y**2)
# Есть ли ограничения по x и y? 1-да / 0 – нет
# 0

# %% [markdown]
# Метод лагранжа (вращающийся 3д график будет в отдельном окне если в начале добавить %matplotlib qt)

# %%
# %matplotlib qt

functions = User()
functions.userAnswer()
# Out:
# Каким методом для нахождения экстремумов хотите воспользоваться? 1 - Обычный способ / 2 - Метод Лагранжа
# 2
# Введите функцию f(x, y). Например:  4*y**2 + x**2
# 4*y**2 + x**2
# Ввод условия(ограничения).
# Введите левую часть ограничения. Например: x**2 + y**2
# x**2 + y**2
# Введите правую часть ограничения. Например: 25
# 25
# Есть ли ограничения по x и y? 1-да / 0 – нет
# 0
